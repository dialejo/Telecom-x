# %% [markdown]
# #📌 Extracción

# %% [markdown]
# https://app.aluracursos.com/course/visualizacion-datos-graficos-bibliotecas-python
#
# https://app.aluracursos.com/course/pandas-transformacion-manipulacion-datos
#
# https://app.aluracursos.com/course/pandas-e-s-diferentes-formatos-archivo
#
# https://app.aluracursos.com/course/pandas-conociendo-biblioteca

# %% [markdown]
# ## **Importando los Datos**

# %%
import pandas as pd
#importando la data
url_data = '/content/drive/MyDrive/Challenge telecom x/TelecomX_Data.json'
df = pd.read_json(url_data)

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %% [markdown]
# ##**Normalizando el DataFrame**

# %%
#Columnas que tienen diccionarios
columnas_anidadas = ['customer','phone','internet','account']

# %%
#normalizando las columnas con diccionarios
for columns in columnas_anidadas:
  df_anidado = pd.json_normalize(df[columns])
  df = pd.concat([df, df_anidado],axis = 1)

df.drop(columnas_anidadas,axis = 1,inplace = True)

# %%
df.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %% [markdown]
# #🔧 Transformación

# %%
import numpy as np

# %%
df.shape
# Out:
# (7267, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
df.dtypes
# Out:
# customerID           object
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# dtype: object

# %% [markdown]
# ##**Eliminando Datos no validos**

# %%
# Función para detectar valores que no son numéricos válidos
def es_numero_valido(x):
    try:
        float(x)
        return True
    except:
        return False

# Filtrar valores no convertibles
valores_problema = df[~df['Charges.Total'].apply(es_numero_valido)]['Charges.Total'].unique()

print("Valores problemáticos:")
print(valores_problema)
# Out:
# Valores problemáticos:
# [' ']

# %%
#eliminando posibles errores de string
df['Charges.Total'] = df['Charges.Total'].replace('', np.nan)
df['Charges.Total']= df['Charges.Total'].apply(lambda x: x.replace(',','').replace('$','').strip() if isinstance(x, str) else x)

# %%
df['Charges.Total'].isna().sum()
# Out:
# np.int64(11)

# %%
df['Charges.Total']= df['Charges.Total'].astype(np.float64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   int64
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %%
#revisando las filas que el cargo total es 0
filter_nan = df[df['Charges.Total'].isna()]
filter_nan
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 975   1371-DWPAZ    No  Female              0     Yes        Yes       0
# 1775  2520-SGTTA    No  Female              0     Yes        Yes       0
# 1955  2775-SEFEE    No    Male              0      No        Yes       0
# 2075  2923-ARZLG    No    Male              0     Yes        Yes       0
# 2232  3115-CZMZD    No    Male              0      No        Yes       0
# 2308  3213-VVOLG    No    Male              0     Yes        Yes       0
# 2930  4075-WKNIU    No  Female              0     Yes        Yes       0
# 3134  4367-NUYAO    No    Male              0     Yes        Yes       0
# 3203  4472-LVYGI    No  Female              0     Yes        Yes       0
# 4169  5709-LVOEQ    No  Female              0     Yes        Yes       0
# 5599  7644-OMVMY    No    Male              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# ...

# %%
# despues de analizar las filas podemos concluir que como el tenuere es 0 eso significa que el charge total es nan lo podemos poner como cero
df['Charges.Total'] = df['Charges.Total'].fillna(0)

# %%
#revisando que la data este limpia
filter_nan = df[df['Charges.Total'].isna()]
filter_nan
# Out:
# Empty DataFrame
# Columns: [customerID, Churn, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, Charges.Monthly, Charges.Total]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.isna().sum()
# Out:
# customerID          0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
# deberiamos tener ya la misma cantidad de datos en todas las columnas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   int64
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %%
# revisando valores duplicados, en este caso si el dustomer ID se repite seria un valor duplicado
df.duplicated('customerID').sum()
# Out:
# np.int64(0)

# %%
#Revisando los datos nulos del Churn
filter = df[df['Churn']=='']
filter
# Out:
# Empty DataFrame
# Columns: [customerID, Churn, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, Charges.Monthly, Charges.Total]
# Index: []
#
# [0 rows x 21 columns]

# %%
#eliminando los datos nulos del Churn
df = df[df['Churn']!='']

# %%
df['Churn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df.sample(5)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 4672  6397-JNZZG   Yes  Female              1     Yes         No      43
# 1997  2826-DXLQO    No    Male              1     Yes         No       7
# 4345  5961-VUSRV    No  Female              0      No         No      12
# 1561  2230-XTUWL    No  Female              0     Yes        Yes      48
# 5799  7929-DMBCV    No  Female              0     Yes         No      20
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# 4672           No  No phone service             DSL  ...                  Yes
# 1997           No  No phone service             DSL  ...                   No
# 4345          Yes                No              No  ...  No internet service
# 1561          Yes                No              No  ...  No internet service
# 5799          Yes                No     Fiber optic  ...                   No
#
# ...

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# ##**Churn by tenure**

# %%
#agrupando churn by

df_by_tenure = df.groupby('tenure')['Churn'].value_counts().unstack()
df_by_tenure
# Out:
# Churn      No    Yes
# tenure
# 0        11.0    NaN
# 1       233.0  380.0
# 2       115.0  123.0
# 3       106.0   94.0
# 4        93.0   83.0
# ...       ...    ...
# 68       91.0    9.0
# 69       87.0    8.0
# 70      108.0   11.0
# 71      164.0    6.0
# 72      356.0    6.0
#
# [73 rows x 2 columns]

# %%
df_by_tenure['Yes'] = df_by_tenure['Yes'].fillna(0)
df_by_tenure
# Out:
# Churn      No    Yes
# tenure
# 0        11.0    0.0
# 1       233.0  380.0
# 2       115.0  123.0
# 3       106.0   94.0
# 4        93.0   83.0
# ...       ...    ...
# 68       91.0    9.0
# 69       87.0    8.0
# 70      108.0   11.0
# 71      164.0    6.0
# 72      356.0    6.0
#
# [73 rows x 2 columns]

# %%
df_by_tenure.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73 entries, 0 to 72
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   No      73 non-null     float64
#  1   Yes     73 non-null     float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_by_tenure_reset = df_by_tenure.reset_index()
df_long = df_by_tenure_reset.melt(id_vars='tenure',
                                  value_vars=['Yes', 'No'],
                                  var_name='Churn',
                                  value_name='Count')
df_long.head()
# Out:
#    tenure Churn  Count
# 0       0   Yes    0.0
# 1       1   Yes  380.0
# 2       2   Yes  123.0
# 3       3   Yes   94.0
# 4       4   Yes   83.0

# %% [markdown]
# ###**Tabla Dinamica Churn**

# %%
fig = px.line(df_long, x='tenure', y='Count',color='Churn',
              title='Churn Trend by Tenure (1 to 72 months)',
              markers=True)
fig.update_layout(width = 800, height= 400, xaxis = {'tickangle': -45},
                  xaxis_title='meses',yaxis_title = 'Number of churn(yes)',
                  font_family ='Arial', font_size = 14, font_color = 'grey')
fig.write_html('/content/drive/MyDrive/Graphs/Challenge one/Churn_Trend_by_tenure.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###**Tabla Churn reporte**

# %%
fig, ax = plt.subplots(1,2,figsize=(12, 4))  # axs es un array de ejes

# Primer gráfico: Churn = Yes
ax[0].plot(df_by_tenure.index, df_by_tenure['Yes'], color='red', label='Churn: Yes', linewidth=2)
ax[0].set_title('Churn: Yes', loc='left', fontsize=14)
ax[0].legend()

ax[1].plot(df_by_tenure.index, df_by_tenure['No'], color='red', label='Churn: Yes', linewidth=2)
ax[1].set_title('Churn: Yes', loc='left', fontsize=14)
ax[1].legend()

ymin = 0
ymax = 420

for ax in ax.flat:
  ax.set(xlabel='Meses', ylabel='Number of Churn')
  ax.grid(True, color = 'lightgrey')
  ax.spines['top'].set_visible(False)
  ax.spines['right'].set_visible(False)
  ax.xaxis.set_major_locator(plt.MultipleLocator(5))
  ax.set_ylim(ymin, ymax)

# Título general
fig.suptitle('Churn Trend by Tenure (1 to 72 months)', fontsize=18, ha = 'right')

plt.savefig('/content/drive/MyDrive/Graphs/Challenge one/Churn_Trend_by_tenure.png',transparent=False,dpi=300,bbox_inches='tight')

plt.tight_layout()
plt.show()

# %%
df['PaymentMethod'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Credit card (automatic)',
#        'Bank transfer (automatic)'], dtype=object)

# %%
df[(df['Churn']=='Yes') & (df['PaymentMethod']=='Mailed check')].value_counts()
# Out:
# customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines  InternetService  OnlineSecurity       OnlineBackup         DeviceProtection     TechSupport          StreamingTV          StreamingMovies      Contract        PaperlessBilling  PaymentMethod  Charges.Monthly  Charges.Total
# 9985-MWVIX  Yes    Female  0              No       No          1       Yes           No             Fiber optic      No                   No                   No                   No                   No                   No                   Month-to-month  Yes               Mailed check   70.15            70.15            1
# 0013-EXCHZ  Yes    Female  1              Yes      No          3       Yes           No             Fiber optic      No                   No                   No                   Yes                  Yes                  No                   Month-to-month  Yes               Mailed check   83.90            267.4            1
# ...

# %%
df['PaymentMethod'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Credit card (automatic)',
#        'Bank transfer (automatic)'], dtype=object)

# %%
filter = df[(df['Churn']=='Yes') & (df['tenure']<2) & (df['gender']=='Male')]
filter
# Out:
#       customerID Churn gender  SeniorCitizen Partner Dependents  tenure  \
# 19    0023-HGHWL   Yes   Male              1      No         No       1
# 64    0107-WESLM   Yes   Male              0      No         No       1
# 65    0107-YHINA   Yes   Male              0      No        Yes       1
# 143   0231-LXVAP   Yes   Male              0      No         No       1
# 185   0295-PPHDO   Yes   Male              0      No         No       1
# ...          ...   ...    ...            ...     ...        ...     ...
# 7020  9661-MHUMO   Yes   Male              1     Yes        Yes       1
# 7063  9725-SCPZG   Yes   Male              0      No        Yes       1
# 7067  9732-KPKBW   Yes   Male              0      No         No       1
# 7108  9787-XVQIU   Yes   Male              0      No         No       1
# 7126  9804-ICWBG   Yes   Male              0      No         No       1
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# ...

# %% [markdown]
# ##**Analisis 0 a 2 meses Tenuere**

# %%
df_analisis_02_tenurer = df[(df['tenure']>=0) & (df['Churn']=='Yes') & (df['tenure']<=3)]
df_analisis_02_tenurer.head()
# Out:
#     customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 4   0013-EXCHZ   Yes  Female              1     Yes         No       3
# 19  0023-HGHWL   Yes    Male              1      No         No       1
# 25  0032-PGELS   Yes  Female              0     Yes        Yes       1
# 41  0067-DKWBL   Yes    Male              1      No         No       2
# 64  0107-WESLM   Yes    Male              0      No         No       1
#
#    PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# 4           Yes                No     Fiber optic  ...                   No
# 19           No  No phone service             DSL  ...                   No
# 25           No  No phone service             DSL  ...                   No
# 41          Yes                No             DSL  ...                   No
# 64          Yes                No              No  ...  No internet service
#
#        DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
conteo_by_payment = df_analisis_02_tenurer['PaymentMethod'].value_counts().reset_index().sort_values(by='count',ascending=False)
conteo_by_payment.head()
# Out:
#                PaymentMethod  count
# 0           Electronic check    350
# 1               Mailed check    172
# 2  Bank transfer (automatic)     38
# 3    Credit card (automatic)     37

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax = sns.barplot(data=conteo_by_payment,x='count',y='PaymentMethod',orient='h',palette='mako')
ax.set_title('amount of Chur by payment method for the first 3 months',
       loc ='left', fontsize = 16)
ax.set_xlabel('Number of churn by payment method', fontsize = 14)
ax.set_ylabel('')
ax.set_frame_on(False)
ax.tick_params(axis='y',which = 'both', length = 0)
ax.xaxis.set_visible(False)

for i,j in enumerate(conteo_by_payment['count']):
  ax.text(j+2,i,str(j),color='black',fontsize=12,ha='left',va='center')

fig.savefig('/content/drive/MyDrive/Challenge telecom x/Churn_by_payment_method.png',transparent=False,dpi=300,bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-136-1260fe89dc69>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# #📄Informe final
